# %% [markdown]
# # GeoPandas

# %% [markdown]
# [GeoPandas](http://geopandas.org/) es un proyecto de software libre que extiende los tipos de datos de [Pandas](http://pandas.pydata.org/) para incorporar objetos geométricos (puntos, líneas, polígonos, etc). GeoPandas se apoya en las bibliotecas [Shapely](https://pypi.org/project/Shapely/) para realizar las operaciones geométricas, [Fiona](https://github.com/Toblerity/Fiona) para acceder a los datos (ej. en archivos) y [Descartes](https://bitbucket.org/sgillies/descartes/src/default/) y [Matplotlib](https://matplotlib.org/) para graficación.
#
# El objetivo de GeoPandas es facilitar el trabajo con datos geoespaciales en el lenguaje Python, lo que se logra a través de la implementación de estructuras que permiten manejar simultáneamente grandes cantidades de datos. Las dos estructuras principales de GeoPandas son:
#
# - [GeoSeries](http://geopandas.org/data_structures.html#geoseries): es un vector en el que cada elemento es un conjunto de una o varias geometrías correspondientes a una observación. Por ejemplo, el polígono (o multipolígono) que representa una provincia.
# - [GeoDataFrame](http://geopandas.org/data_structures.html#geodataframe): es una estructura tabular (i.e. con filas y columnas) de datos geométricos y no geométricos (ej. textos, números). El conjunto de geometrías se implementa a través de GeoSeries.
#
# Con estas estructuras, es posible realizar desde Python operaciones "masivas" de datos, las cuales de otra forma requerirían de una base de datos geoespacial (ej. [PostgreSQL/PostGIS](https://postgis.net/)).

# %% [markdown]
# ## Instalación

# %% [markdown]
# Para instalar el paquete mediante **conda**, debe ejecutarse la siguiente instrucción desde la línea de comandos de Anaconda:
#
# ```
# conda install geopandas
# ```

# %% [markdown]
# ## Importación

# %%
# %matplotlib inline

import pandas as pd
import geopandas

from shapely.geometry import Point, Polygon

# Cantidad máxima de registros que se despliegan en un GeoDataFrame
pd.options.display.max_rows = 10

# %% [markdown]
# ## Ejemplos

# %% [markdown]
# Para los siguientes ejemplos, se utilizará el _shapefile_ de países de [Natural Earth](https://www.naturalearthdata.com/), disponible en [http://www.naturalearthdata.com/downloads/110m-cultural-vectors/110m-admin-0-countries/](http://www.naturalearthdata.com/downloads/110m-cultural-vectors/110m-admin-0-countries/). El enlace anterior brinda acceso a un archivo ZIP que debe colocarse en el directorio de datos (/datos). Una vez hecho esto, se procede a almacenar los datos en un GeoDataFrame, a través de la función **read_file()**.

# %%
paises = geopandas.read_file("zip://./datos/ne_110m_admin_0_countries.zip")
# si se descomprimió el archivo, debe usarse el comando:
# paises = geopandas.read_file("datos/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp")

# %%
# paises es una variable del tipo GeoDataFrame
type(paises)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ### Visualización de datos tabulares

# %% [markdown]
# Los datos de un GeoDataFrame pueden inspeccionarse con la función **head()**, la cual retorna los primeros registros de un GeoDataFrame. Nótese la columna con el tipo de datos geométricos.

# %%
paises.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE                        ADMIN ADM0_A3  \
# 0         0      2  Sovereign country                         Fiji     FJI
# 1         0      2  Sovereign country  United Republic of Tanzania     TZA
# 2         0      2      Indeterminate               Western Sahara     SAH
# 3         0      2  Sovereign country                       Canada     CAN
# 4         1      2            Country     United States of America     USA
#
#    ...  NAME_KO                       NAME_NL            NAME_PL  \
# 0  ...       피지                          Fiji              Fidżi
# 1  ...     탄자니아                      Tanzania           Tanzania
# 2  ...     서사하라             Westelijke Sahara   Sahara Zachodnia
# 3  ...      캐나다                        Canada             Kanada
# 4  ...       미국  Verenigde Staten van Amerika  Stany Zjednoczone
#
#            NAME_PT                    NAME_RU     NAME_SV  \
# 0             Fiji                      Фиджи        Fiji
# 1         Tanzânia                   Танзания    Tanzania
# 2  Saara Ocidental            Западная Сахара  Västsahara
# 3           Canadá                     Канада      Kanada
# 4   Estados Unidos  Соединённые Штаты Америки         USA
#
#                        NAME_TR     NAME_VI NAME_ZH  \
# 0                         Fiji        Fiji      斐濟
# 1                     Tanzanya    Tanzania    坦桑尼亚
# 2                   Batı Sahra  Tây Sahara    西撒哈拉
# 3                       Kanada      Canada     加拿大
# 4  Amerika Birleşik Devletleri      Hoa Kỳ      美国
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 95 columns]

# %%
# Despliegue de las geometrías
paises.geometry
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %%
# paises.geometry es una variable del tipo GeoSeries
type(paises.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
# Despliegue de la lista de columnas
paises.columns
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF', 'GEOUNIT',
#        'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF', 'NAME', 'NAME_LONG',
#        'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV', 'POSTAL', 'FORMAL_EN',
#        'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0', 'NOTE_BRK', 'NAME_SORT',
#        'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8', 'MAPCOLOR9', 'MAPCOLOR13',
#        'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR', 'LASTCENSUS',
#        'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'WIKIPEDIA', 'FIPS_10_', 'ISO_A2',
#        'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'WOE_ID',
#        'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS', 'ADM0_A3_US', 'ADM0_A3_UN',
#        'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB',
#        'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART', 'MIN_ZOOM',
#        'MIN_LABEL', 'MAX_LABEL', 'NE_ID', 'WIKIDATAID', 'NAME_AR', 'NAME_BN',
#        'NAME_DE', 'NAME_EN', 'NAME_ES', 'NAME_FR', 'NAME_EL', 'NAME_HI',
#        'NAME_HU', 'NAME_ID', 'NAME_IT', 'NAME_JA', 'NAME_KO', 'NAME_NL',
#        'NAME_PL', 'NAME_PT', 'NAME_RU', 'NAME_SV', 'NAME_TR', 'NAME_VI',
#        'NAME_ZH', 'geometry'],
#       dtype='object')

# %%
# Despliegue de un subconjunto de columnas
paises[['NAME_ES','CONTINENT','ECONOMY']]
# Out:
#                NAME_ES      CONTINENT                    ECONOMY
# 0                 Fiyi        Oceania       6. Developing region
# 1             Tanzania         Africa  7. Least developed region
# 2    Sahara Occidental         Africa  7. Least developed region
# 3               Canadá  North America    1. Developed region: G7
# 4       Estados Unidos  North America    1. Developed region: G7
# ..                 ...            ...                        ...
# 172             Serbia         Europe       6. Developing region
# 173         Montenegro         Europe       6. Developing region
# 174             Kosovo         Europe       6. Developing region
# 175  Trinidad y Tobago  North America       6. Developing region
# 176      Sudán del Sur         Africa  7. Least developed region
#
# [177 rows x 3 columns]

# %% [markdown]
# **Funciones en columnas**

# %%
# Promedio
paises['POP_EST'].mean()
# Out:
# 41712369.84180791

# %%
# Máximo
paises['POP_EST'].max()
# Out:
# 1379302771

# %%
# Mínimo
paises['POP_EST'].min()
# Out:
# 140

# %% [markdown]
# **Filtrado**

# %%
paises[paises['CONTINENT'] == 'Africa']
# Out:
#           featurecla  scalerank  LABELRANK                        SOVEREIGNT  \
# 1    Admin-0 country          1          3       United Republic of Tanzania
# 2    Admin-0 country          1          7                    Western Sahara
# 11   Admin-0 country          1          2  Democratic Republic of the Congo
# 12   Admin-0 country          1          6                           Somalia
# 13   Admin-0 country          1          2                             Kenya
# ..               ...        ...        ...                               ...
# 166  Admin-0 country          1          5                          Djibouti
# 167  Admin-0 country          1          5                        Somaliland
# 168  Admin-0 country          1          3                            Uganda
# 169  Admin-0 country          1          3                            Rwanda
# 176  Admin-0 country          1          3                       South Sudan
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE  \
# 1      TZA         0      2  Sovereign country
# 2      SAH         0      2      Indeterminate
# 11     COD         0      2  Sovereign country
# 12     SOM         0      2  Sovereign country
# 13     KEN         0      2  Sovereign country
# ..     ...       ...    ...                ...
# 166    DJI         0      2  Sovereign country
# 167    SOL         0      2      Indeterminate
# 168    UGA         0      2  Sovereign country
# 169    RWA         0      2  Sovereign country
# 176    SDS         0      2  Sovereign country
#
#                                 ADMIN ADM0_A3  ...    NAME_KO  \
# 1         United Republic of Tanzania     TZA  ...       탄자니아
# 2                      Western Sahara     SAH  ...       서사하라
# 11   Democratic Republic of the Congo     COD  ...  콩고 민주 공화국
# 12                            Somalia     SOM  ...       소말리아
# 13                              Kenya     KEN  ...         케냐
# ..                                ...     ...  ...        ...
# 166                          Djibouti     DJI  ...        지부티
# 167                        Somaliland     SOL  ...      소말릴란드
# 168                            Uganda     UGA  ...        우간다
# 169                            Rwanda     RWA  ...        르완다
# 176                       South Sudan     SDS  ...        남수단
#
#                NAME_NL                        NAME_PL  \
# 1             Tanzania                       Tanzania
# 2    Westelijke Sahara               Sahara Zachodnia
# 11      Congo-Kinshasa  Demokratyczna Republika Konga
# 12             Somalië                        Somalia
# 13               Kenia                          Kenia
# ..                 ...                            ...
# 166           Djibouti                        Dżibuti
# 167         Somaliland                     Somaliland
# 168            Oeganda                         Uganda
# 169             Rwanda                         Rwanda
# 176        Zuid-Soedan               Sudan Południowy
#
#                             NAME_PT                           NAME_RU  \
# 1                          Tanzânia                          Танзания
# 2                   Saara Ocidental                   Западная Сахара
# 11   República Democrática do Congo  Демократическая Республика Конго
# 12                          Somália                            Сомали
# 13                           Quénia                             Кения
# ..                              ...                               ...
# 166                        Djibouti                           Джибути
# 167                    Somalilândia                        Сомалиленд
# 168                          Uganda                            Уганда
# 169                          Ruanda                            Руанда
# 176                    Sudão do Sul                       Южный Судан
#
#             NAME_SV                       NAME_TR                 NAME_VI  \
# 1          Tanzania                      Tanzanya                Tanzania
# 2        Västsahara                    Batı Sahra              Tây Sahara
# 11   Kongo-Kinshasa  Demokratik Kongo Cumhuriyeti  Cộng hòa Dân chủ Congo
# 12          Somalia                        Somali                 Somalia
# 13            Kenya                         Kenya                   Kenya
# ..              ...                           ...                     ...
# 166        Djibouti                        Cibuti                Djibouti
# 167      Somaliland                    Somaliland              Somaliland
# 168          Uganda                        Uganda                  Uganda
# 169          Rwanda                        Ruanda                  Rwanda
# 176        Sydsudan                   Güney Sudan               Nam Sudan
#
#      NAME_ZH                                           geometry
# 1       坦桑尼亚  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2       西撒哈拉  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 11   刚果民主共和国  POLYGON ((29.34000 -4.49998, 29.51999 -5.41998...
# 12       索马里  POLYGON ((41.58513 -1.68325, 40.99300 -0.85829...
# 13       肯尼亚  POLYGON ((39.20222 -4.67677, 37.76690 -3.67712...
# ..       ...                                                ...
# 166      吉布提  POLYGON ((42.35156 12.54223, 42.77964 12.45542...
# 167     索马里兰  POLYGON ((48.94820 11.41062, 48.94820 11.41062...
# 168      乌干达  POLYGON ((33.90371 -0.95000, 31.86617 -1.02736...
# 169      卢旺达  POLYGON ((30.41910 -1.13466, 30.81613 -1.69891...
# 176      南苏丹  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [51 rows x 95 columns]

# %%
paises[paises['POP_EST'] <= 100000]
# Out:
#           featurecla  scalerank  LABELRANK      SOVEREIGNT SOV_A3  ADM0_DIF  \
# 20   Admin-0 country          1          5  United Kingdom    GB1         1
# 22   Admin-0 country          1          3         Denmark    DN1         1
# 23   Admin-0 country          3          6          France    FR1         1
# 159  Admin-0 country          1          4      Antarctica    ATA         0
#
#      LEVEL           TYPE                                ADMIN ADM0_A3  ...  \
# 20       2     Dependency                     Falkland Islands     FLK  ...
# 22       2        Country                            Greenland     GRL  ...
# 23       2     Dependency  French Southern and Antarctic Lands     ATF  ...
# 159      2  Indeterminate                           Antarctica     ATA  ...
#
#           NAME_KO                                     NAME_NL  \
# 20        포클랜드 제도                            Falklandeilanden
# 22           그린란드                                   Groenland
# 23   프랑스령 남방 및 남극  Franse Zuidelijke en Antarctische Gebieden
# 159            남극                                  Antarctica
#
#                                             NAME_PL  \
# 20                                        Falklandy
# 22                                       Grenlandia
# 23   Francuskie Terytoria Południowe i Antarktyczne
# 159                                      Antarktyda
#
#                                     NAME_PT  \
# 20                           Ilhas Malvinas
# 22                              Gronelândia
# 23   Terras Austrais e Antárticas Francesas
# 159                               Antártida
#
#                                            NAME_RU                   NAME_SV  \
# 20                            Фолклендские острова            Falklandsöarna
# 22                                      Гренландия                  Grönland
# 23   Французские Южные и Антарктические территории  Franska sydterritorierna
# 159                                     Антарктида                 Antarktis
#
#                                     NAME_TR  \
# 20                         Falkland Adaları
# 22                                 Grönland
# 23   Fransız Güney ve Antarktika Toprakları
# 159                              Antarktika
#
#                                           NAME_VI NAME_ZH  \
# 20                              Quần đảo Falkland   福克兰群岛
# 22                                      Greenland     格陵兰
# 23   Vùng đất phía Nam và châu Nam Cực thuộc Pháp  法属南部领地
# 159                                  Châu Nam Cực     南极洲
#
#                                               geometry
# 20   POLYGON ((-61.20000 -51.85000, -60.00000 -51.2...
# 22   POLYGON ((-46.76379 82.62796, -43.40644 83.225...
# 23   POLYGON ((68.93500 -48.62500, 69.58000 -48.940...
# 159  MULTIPOLYGON (((-48.66062 -78.04702, -48.15140...
#
# [4 rows x 95 columns]

# %% [markdown]
# ### Visualización de datos geoespaciales

# %% [markdown]
# La función [plot()](http://geopandas.org/reference.html#geopandas.GeoDataFrame.plot) proporciona una manera sencilla de visualizar los datos en un mapa.

# %%
paises.plot()
# Out:
# <AxesSubplot:>

# %%
paises_asia = paises[paises['CONTINENT'] == 'Asia']
paises_asia.plot()
# Out:
# <AxesSubplot:>

# %%
# Cambio de tamaño del mapa
paises_asia.plot(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Colores**

# %%
paises_asia.plot(figsize=(15, 10), cmap="rainbow")
# Out:
# <AxesSubplot:>

# %%
# Colores asignados con base en una columna
paises_asia.plot(figsize=(15, 10), cmap="Blues", column="POP_EST")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Para más opciones de colores, puede consultarse [https://matplotlib.org/users/colormaps.html](https://matplotlib.org/users/colormaps.html).

# %% [markdown]
# #### Visualización de múltiples capas

# %% [markdown]
# Para los siguientes ejemplos, deben descargarse los siguientes _shapefiles_ comprimidos en formato ZIP:
#
# - **Ciudades**: [http://www.naturalearthdata.com/downloads/110m-cultural-vectors/110m-populated-places/](http://www.naturalearthdata.com/downloads/110m-cultural-vectors/110m-populated-places/)
# - **Ríos**: [http://www.naturalearthdata.com/downloads/50m-physical-vectors/50m-rivers-lake-centerlines/](http://www.naturalearthdata.com/downloads/50m-physical-vectors/50m-rivers-lake-centerlines/)
#
# Ambas capas deben copiarse en el directorio de datos. Seguidamente, su contenido se almacena en dos GeoDataFrames:

# %%
ciudades = geopandas.read_file("zip://./datos/ne_110m_populated_places.zip")
rios = geopandas.read_file("zip://./datos/ne_50m_rivers_lake_centerlines.zip")

# %%
ciudades.columns
# Out:
# Index(['SCALERANK', 'NATSCALE', 'LABELRANK', 'FEATURECLA', 'NAME', 'NAMEPAR',
#        'NAMEALT', 'DIFFASCII', 'NAMEASCII', 'ADM0CAP',
#        ...
#        'name_ja', 'name_ko', 'name_nl', 'name_pl', 'name_sv', 'name_tr',
#        'name_vi', 'wdid_score', 'ne_id', 'geometry'],
#       dtype='object', length=120)

# %% [markdown]
# Se crea un subconjunto de datos para el continente africano:

# %%
rios.columns
# Out:
# Index(['scalerank', 'featurecla', 'name', 'note', 'min_zoom', 'name_alt',
#        'min_label', 'name_en', 'label', 'wikidataid', 'name_ar', 'name_bn',
#        'name_de', 'name_es', 'name_fr', 'name_el', 'name_hi', 'name_hu',
#        'name_id', 'name_it', 'name_ja', 'name_ko', 'name_nl', 'name_pl',
#        'name_pt', 'name_ru', 'name_sv', 'name_tr', 'name_vi', 'name_zh',
#        'wdid_score', 'ne_id', 'geometry'],
#       dtype='object')

# %%
paises_africa = paises[paises['CONTINENT'] == 'Africa']

# %%
ax = paises.plot(edgecolor='black', facecolor='none', figsize=(15, 10))
rios.plot(ax=ax, color='blue')
ciudades.plot(ax=ax, color='red')
ax.set(xlim=(-20, 60), ylim=(-40, 70))
# Out:
# [(-20.0, 60.0), (-40.0, 70.0)]

# %% [markdown]
# <div class="alert alert-success">
#  <strong>Ejercicio</strong>:
#
# Descargue del SNIT las capas de:
# * Límite provincial [(http://www.snitcr.go.cr/servicios_ogc_lista_capas?k=bm9kbzo6MjY=&nombre=IGN%20Cartograf%C3%ADa%201:5mil)](http://www.snitcr.go.cr/servicios_ogc_lista_capas?k=bm9kbzo6MjY=&nombre=IGN%20Cartograf%C3%ADa%201:5mil)
# * Aeródromos y red vial [(http://www.snitcr.go.cr/servicios_ogc_lista_capas?k=bm9kbzo6MjY=&nombre=IGN%20Cartograf%C3%ADa%201:5mil)](http://www.snitcr.go.cr/servicios_ogc_lista_capas?k=bm9kbzo6MjY=&nombre=IGN%20Cartograf%C3%ADa%201:5mil)
#
# Despliegue las tres capas en un solo mapa.
#
# </div>

# %% [markdown]
# **Datos geoespaciales en archivos de texto**

# %% [markdown]
# En estos casos, puede crearse un DataFrame convencional a partir del archivo de texto y un conjunto de geometrías a partir de las columnas correspondientes (ej. longitud, latitud). Posteriormente, se crea un GeoDataFrame combinando el DataFrame y las geometrías. A continuación, se presenta un ejemplo.

# %% [markdown]
# Para comenzar, descargue el archivo de datos de presencia en Costa Rica del género de aves [Trogon](https://en.wikipedia.org/wiki/Trogon_(genus)) de [http://api.gbif.org/v1/occurrence/download/request/0021444-190621201848488.zip](http://api.gbif.org/v1/occurrence/download/request/0021444-190621201848488.zip) y descomprímalo.

# %%
# Carga de los datos en un DataFrame
trogones_df = pd.read_csv("datos/0021444-190621201848488.csv", sep='\t')
# Out:
# C:\Users\PC\anaconda3\envs\leccion-12a\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (10,34,35,36,38,40,41,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
trogones_df.head()
# Out:
#        gbifID                            datasetKey  \
# 0  2294676901  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  2294580122  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  2294477093  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  2294476497  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  2294476337  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                         occurrenceID   kingdom    phylum  \
# 0  https://www.inaturalist.org/observations/29508598  Animalia  Chordata
# 1  https://www.inaturalist.org/observations/29133368  Animalia  Chordata
# 2  https://www.inaturalist.org/observations/28748201  Animalia  Chordata
# 3  https://www.inaturalist.org/observations/28748200  Animalia  Chordata
# 4  https://www.inaturalist.org/observations/28748199  Animalia  Chordata
#
#   class          order      family   genus                 species  ...  \
# 0  Aves  Trogoniformes  Trogonidae  Trogon        Trogon caligatus  ...
# 1  Aves  Trogoniformes  Trogonidae  Trogon  Trogon aurantiiventris  ...
# 2  Aves  Trogoniformes  Trogonidae  Trogon          Trogon massena  ...
# 3  Aves  Trogoniformes  Trogonidae  Trogon          Trogon bairdii  ...
# 4  Aves  Trogoniformes  Trogonidae  Trogon            Trogon rufus  ...
#
#   identifiedBy        dateIdentified       license rightsHolder recordedBy  \
# 0          NaN  2019-07-25T14:08:19Z  CC_BY_NC_4_0     cukibapa   cukibapa
# 1          NaN  2019-07-19T20:32:16Z  CC_BY_NC_4_0    lrussoutk  lrussoutk
# 2          NaN  2019-07-13T19:04:47Z  CC_BY_NC_4_0    kmherpkid  kmherpkid
# 3          NaN  2019-07-13T19:04:46Z  CC_BY_NC_4_0    kmherpkid  kmherpkid
# 4          NaN  2019-07-13T19:04:46Z  CC_BY_NC_4_0    kmherpkid  kmherpkid
#
#   typeStatus  establishmentMeans           lastInterpreted   mediaType  \
# 0        NaN                 NaN  2019-07-29T07:55:15.725Z  STILLIMAGE
# 1        NaN                 NaN  2019-07-29T07:53:18.332Z  STILLIMAGE
# 2        NaN                 NaN  2019-07-29T07:51:02.615Z  STILLIMAGE
# 3        NaN                 NaN  2019-07-29T07:51:01.603Z  STILLIMAGE
# 4        NaN                 NaN  2019-07-29T07:51:01.814Z  STILLIMAGE
#
#                                              issue
# 0  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 1  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 2  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 3  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 4  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
#
# [5 rows x 45 columns]

# %%
# Despliegue de un subconjunto de columnas
trogones_df[['species', 'decimalLongitude', 'decimalLatitude', 'eventDate']]
# Out:
#                       species  decimalLongitude  decimalLatitude  \
# 0            Trogon caligatus        -82.805258         9.675457
# 1      Trogon aurantiiventris        -83.659362         8.639661
# 2              Trogon massena        -83.590981         8.477301
# 3              Trogon bairdii        -83.513941         8.413747
# 4                Trogon rufus        -83.580167         8.479169
# ...                       ...               ...              ...
# 66656         Trogon collaris        -84.170190        10.255370
# 66657  Trogon aurantiiventris        -84.705780        10.431394
# 66658          Trogon elegans        -85.619116        10.837858
# 66659  Trogon aurantiiventris        -84.811053        10.311797
# 66660  Trogon aurantiiventris        -84.811053        10.311797
#
#                   eventDate
# 0      2014-01-01T13:21:00Z
# 1      2015-12-28T12:06:00Z
# 2      2019-04-10T05:03:00Z
# 3      2019-04-10T04:59:00Z
# 4      2019-04-09T11:53:00Z
# ...                     ...
# 66656  2007-06-23T00:00:00Z
# 66657  2007-06-22T00:00:00Z
# 66658  2007-06-06T00:00:00Z
# 66659  2006-06-15T00:00:00Z
# 66660  2006-06-14T00:00:00Z
#
# [66661 rows x 4 columns]

# %%
# Se crea una lista de geometrías de puntos
puntos = [Point(xy) for xy in zip(trogones_df["decimalLongitude"], trogones_df["decimalLatitude"])]
puntos[:5]
# Out:
# [<shapely.geometry.point.Point at 0x2a876a47af0>,
#  <shapely.geometry.point.Point at 0x2a876a477f0>,
#  <shapely.geometry.point.Point at 0x2a876a47df0>,
#  <shapely.geometry.point.Point at 0x2a876a47b20>,
#  <shapely.geometry.point.Point at 0x2a876a479d0>]

# %%
# Se combina el DataFrame y las geometrías en un GeoDataFrame, junto con un sistema de coordenadas
trogones=geopandas.GeoDataFrame(trogones_df, crs={"init": "epsg:4326"}, geometry=puntos)
# Out:
# C:\Users\PC\anaconda3\envs\leccion-12a\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
trogones.head()
# Out:
#        gbifID                            datasetKey  \
# 0  2294676901  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  2294580122  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  2294477093  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  2294476497  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  2294476337  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                         occurrenceID   kingdom    phylum  \
# 0  https://www.inaturalist.org/observations/29508598  Animalia  Chordata
# 1  https://www.inaturalist.org/observations/29133368  Animalia  Chordata
# 2  https://www.inaturalist.org/observations/28748201  Animalia  Chordata
# 3  https://www.inaturalist.org/observations/28748200  Animalia  Chordata
# 4  https://www.inaturalist.org/observations/28748199  Animalia  Chordata
#
#   class          order      family   genus                 species  ...  \
# 0  Aves  Trogoniformes  Trogonidae  Trogon        Trogon caligatus  ...
# 1  Aves  Trogoniformes  Trogonidae  Trogon  Trogon aurantiiventris  ...
# 2  Aves  Trogoniformes  Trogonidae  Trogon          Trogon massena  ...
# 3  Aves  Trogoniformes  Trogonidae  Trogon          Trogon bairdii  ...
# 4  Aves  Trogoniformes  Trogonidae  Trogon            Trogon rufus  ...
#
#          dateIdentified       license rightsHolder recordedBy typeStatus  \
# 0  2019-07-25T14:08:19Z  CC_BY_NC_4_0     cukibapa   cukibapa        NaN
# 1  2019-07-19T20:32:16Z  CC_BY_NC_4_0    lrussoutk  lrussoutk        NaN
# 2  2019-07-13T19:04:47Z  CC_BY_NC_4_0    kmherpkid  kmherpkid        NaN
# 3  2019-07-13T19:04:46Z  CC_BY_NC_4_0    kmherpkid  kmherpkid        NaN
# 4  2019-07-13T19:04:46Z  CC_BY_NC_4_0    kmherpkid  kmherpkid        NaN
#
#   establishmentMeans           lastInterpreted   mediaType  \
# 0                NaN  2019-07-29T07:55:15.725Z  STILLIMAGE
# 1                NaN  2019-07-29T07:53:18.332Z  STILLIMAGE
# 2                NaN  2019-07-29T07:51:02.615Z  STILLIMAGE
# 3                NaN  2019-07-29T07:51:01.603Z  STILLIMAGE
# 4                NaN  2019-07-29T07:51:01.814Z  STILLIMAGE
#
#                                              issue                   geometry
# 0  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED  POINT (-82.80526 9.67546)
# 1  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED  POINT (-83.65936 8.63966)
# 2  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED  POINT (-83.59098 8.47730)
# 3  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED  POINT (-83.51394 8.41375)
# 4  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED  POINT (-83.58017 8.47917)
#
# [5 rows x 46 columns]

# %%
# Mapa de los registros de presencia de trogones
trogones.plot(figsize=(15, 10), color="red", markersize=5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-success">
#  <strong>Ejercicio</strong>:
#
# Despliegue los registros de presencia de trogones sobre la capa de provincias del SNIT.
#
# </div>

# %%
provincias = geopandas.read_file("datos/cr_provincias_wgs84_snit_ign_2019.shp")

ax = provincias.plot(edgecolor='black', facecolor='none', figsize=(15, 10))
trogones.plot(ax=ax, color='red', markersize=5)
ax.set(xlim=(-86.5, -82), ylim=(8, 11.25))
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: datos/cr_provincias_wgs84_snit_ign_2019.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-36-c3e96a48f8c0> in <module>
# ----> 1 provincias = geopandas.read_file("datos/cr_provincias_wgs84_snit_ign_2019.shp")
#       2
#       3 ax = provincias.plot(edgecolor='black', facecolor='none', figsize=(15, 10))
#       4 trogones.plot(ax=ax, color='red', markersize=5)
#       5 ax.set(xlim=(-86.5, -82), ylim=(8, 11.25))
#
# ~\anaconda3\envs\leccion-12a\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
#      97
#      98             # In a future Fiona release the crs attribute of features will
#
# ~\anaconda3\envs\leccion-12a\lib\site-packages\fiona\env.py in wrapper(*args, **kwargs)
#     398     def wrapper(*args, **kwargs):
#     399         if local._env:
# --> 400             return f(*args, **kwargs)
#     401         else:
#     402             if isinstance(args[0], str):
#
# ~\anaconda3\envs\leccion-12a\lib\site-packages\fiona\__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     254
#     255         if mode in ('a', 'r'):
# --> 256             c = Collection(path, mode, driver=driver, encoding=encoding,
#     257                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     258         elif mode == 'w':
#
# ~\anaconda3\envs\leccion-12a\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     162             if self.mode == 'r':
#     163                 self.session = Session()
# --> 164                 self.session.start(self, **kwargs)
#     165             elif self.mode in ('a', 'w'):
#     166                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: datos/cr_provincias_wgs84_snit_ign_2019.shp: No such file or directory
